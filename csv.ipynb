# %%
import pandas as pd
import numpy as np
from datetime import datetime
import datetime as dt

# %%
filea='./csv_25/bres_qtableno_euc_25.csv'
fileb='./csv_25/bres_qtabletraceno_euc_25.csv'
filec='./csv_25/bres_sarsano_euc_25.csv'
filed='./csv_25/bres_sarsatraceno_euc_25.csv'

# %%
print(filea)
df=pd.read_csv(filea,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[24, 24]":
        if row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
    else:
        if row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])


print("===============30%===================")
print((25-len(count3))/25)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((25-len(count4))/25)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============Average===================")
print((50-len(count3+count4))/50)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000

    
f=avg/len(l3+l4)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./csv_25/bres_qtableno_euc_25.csv
# ===============30%===================
# 1.0
# 53.44
# 0:35:07.465211
# ===============40%===================
# 1.0
# 52.24
# 0:34:44.021210
# ===============Average===================
# 1.0
# 52.84
# 0:34:55.743211

# %%
print(fileb)
df=pd.read_csv(fileb,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[24, 24]":
        if row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
    else:
        if row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])


print("===============30%===================")
print((25-len(count3))/25)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((25-len(count4))/25)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============Average===================")
print((50-len(count3+count4))/50)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000

    
f=avg/len(l3+l4)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./csv_25/bres_qtabletraceno_euc_25.csv
# ===============30%===================
# 0.84
# 55.04761904761905
# 0:25:57.444026
# ===============40%===================
# 0.96
# 54.25
# 0:25:05.910508
# ===============Average===================
# 0.9
# 54.62222222222222
# 0:25:29.959483

# %%
print(filec)
df=pd.read_csv(filec,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[24, 24]":
        if row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
    else:
        if row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])


print("===============30%===================")
print((25-len(count3))/25)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((25-len(count4))/25)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============Average===================")
print((50-len(count3+count4))/50)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000

    
f=avg/len(l3+l4)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./csv_25/bres_sarsano_euc_25.csv
# ===============30%===================
# 1.0
# 52.48
# 0:35:26.043030
# ===============40%===================
# 1.0
# 51.6
# 0:33:31.986086
# ===============Average===================
# 1.0
# 52.04
# 0:34:29.014558

# %%
print(filed)
df=pd.read_csv(filed,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[24, 24]":
        if row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
    else:
        if row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])


print("===============30%===================")
print((25-len(count3))/25)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((25-len(count4))/25)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============Average===================")
print((50-len(count3+count4))/50)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000

    
f=avg/len(l3+l4)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./csv_25/bres_sarsatraceno_euc_25.csv
# ===============30%===================
# 0.92
# 54.52173913043478
# 0:29:22.459668
# ===============40%===================
# 0.88
# 53.90909090909091
# 0:28:46.828538
# ===============Average===================
# 0.9
# 54.22222222222222
# 0:29:05.040005

# %%
##BELOW WORKS FOR 11 FILES

# %%
#df1=pd.read_csv('res_sarsatraceprox2_opt5.csv',header=0)
#df2=pd.read_csv('res_sarsatraceprox2_opt11.csv',header=0)
#df3=pd.read_csv('res_sarsatraceprox2_opt15.csv',header=0)
#df4=pd.read_csv('res_sarsatraceprox2_no21.csv',header=0)
#df5=pd.read_csv('res_sarsatraceprox2_no25.csv',header=0)

#df = pd.concat([df4,df5], ignore_index=True)
df=pd.read_csv('./bres_sarsatraceno_base.csv',header=0)

filea='./bres_qtable_che.csv'
fileb='./bres_qtabletrace_che.csv'
filec='./bres_sarsa_che.csv'
filed='./bres_sarsatrace_che.csv'

# %%
print(filea)
df=pd.read_csv(filea,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[10, 10]":
        if row["OBS"]==0.2:
            l2.append(row["TIME"][7:])
            m2.append(row["STP_PL"])
        elif row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
        elif row["OBS"]==0.5:
            l5.append(row["TIME"][7:])
            m5.append(row["STP_PL"])

    else:
        if row["OBS"]==0.2:
            count2.append(row["TIME"][7:])
        elif row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])
        elif row["OBS"]==0.5:
            count5.append(row["TIME"][7:])
'''
print("===============20%===================")
print((100-len(count2))/100)
print(np.average(m2))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l2)
print(str(dt.timedelta(microseconds=f)))

print("===============30%===================")
print((100-len(count3))/100)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((100-len(count4))/100)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============50%===================")
print((100-len(count5))/100)
print(np.average(m5))
avg=0
tmp=0
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l5)
print(str(dt.timedelta(microseconds=f)))     
'''

print("===============Average===================")
print((400-len(count2+count3+count4+count5))/400)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
    
f=avg/len(l2+l3+l4+l5)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./bres_qtable_che.csv
# ===============Average===================
# 0.885
# 20.943502824858758
# 0:01:00.644172

# %%
print(fileb)
df=pd.read_csv(fileb,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[10, 10]":
        if row["OBS"]==0.2:
            l2.append(row["TIME"][7:])
            m2.append(row["STP_PL"])
        elif row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
        elif row["OBS"]==0.5:
            l5.append(row["TIME"][7:])
            m5.append(row["STP_PL"])

    else:
        if row["OBS"]==0.2:
            count2.append(row["TIME"][7:])
        elif row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])
        elif row["OBS"]==0.5:
            count5.append(row["TIME"][7:])
'''
print("===============20%===================")
print((100-len(count2))/100)
print(np.average(m2))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l2)
print(str(dt.timedelta(microseconds=f)))


print("===============30%===================")
print((100-len(count3))/100)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((100-len(count4))/100)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============50%===================")
print((100-len(count5))/100)
print(np.average(m5))
avg=0
tmp=0
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l5)
print(str(dt.timedelta(microseconds=f)))
'''
print("===============Average===================")
print((400-len(count2+count3+count4+count5))/400)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
    
f=avg/len(l2+l3+l4+l5)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./bres_qtabletrace_che.csv
# ===============Average===================
# 1.0
# 21.92
# 0:00:36.155883

# %%
print(filec)
df=pd.read_csv(filec,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[10, 10]":
        if row["OBS"]==0.2:
            l2.append(row["TIME"][7:])
            m2.append(row["STP_PL"])
        elif row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
        elif row["OBS"]==0.5:
            l5.append(row["TIME"][7:])
            m5.append(row["STP_PL"])

    else:
        if row["OBS"]==0.2:
            count2.append(row["TIME"][7:])
        elif row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])
        elif row["OBS"]==0.5:
            count5.append(row["TIME"][7:])
'''
print("===============20%===================")
print((100-len(count2))/100)
print(np.average(m2))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l2)
print(str(dt.timedelta(microseconds=f)))


print("===============30%===================")
print((100-len(count3))/100)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((100-len(count4))/100)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============50%===================")
print((100-len(count5))/100)
print(np.average(m5))
avg=0
tmp=0
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l5)
print(str(dt.timedelta(microseconds=f)))
'''
print("===============Average===================")
print((400-len(count2+count3+count4+count5))/400)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
    
f=avg/len(l2+l3+l4+l5)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./bres_sarsa_che.csv
# ===============Average===================
# 0.8975
# 20.958217270194986
# 0:01:02.337896

# %%
print(filed)
df=pd.read_csv(filed,header=0)
df.sort_values(["NAME"], axis=0,ascending=[False],inplace=True)

l2=[]
l3=[]
l4=[]
l5=[]

m2=[]
m3=[]
m4=[]
m5=[]

count2=[]
count3=[]
count4=[]
count5=[]


for index, row in df.iterrows():
    
    if row["PATH"][-12:-4]=="[10, 10]":
        if row["OBS"]==0.2:
            l2.append(row["TIME"][7:])
            m2.append(row["STP_PL"])
        elif row["OBS"]==0.3:
            l3.append(row["TIME"][7:])
            m3.append(row["STP_PL"])
        elif row["OBS"]==0.4:
            l4.append(row["TIME"][7:])
            m4.append(row["STP_PL"])
        elif row["OBS"]==0.5:
            l5.append(row["TIME"][7:])
            m5.append(row["STP_PL"])

    else:
        if row["OBS"]==0.2:
            count2.append(row["TIME"][7:])
        elif row["OBS"]==0.3:
            count3.append(row["TIME"][7:])
        elif row["OBS"]==0.4:
            count4.append(row["TIME"][7:])
        elif row["OBS"]==0.5:
            count5.append(row["TIME"][7:])

'''            
print("===============20%===================")
print((100-len(count2))/100)
print(np.average(m2))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l2)
print(str(dt.timedelta(microseconds=f)))


print("===============30%===================")
print((100-len(count3))/100)
print(np.average(m3))
avg=0
tmp=0
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l3)
print(str(dt.timedelta(microseconds=f)))


print("===============40%===================")
print((100-len(count4))/100)
print(np.average(m4))
avg=0
tmp=0
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l4)
print(str(dt.timedelta(microseconds=f)))

print("===============50%===================")
print((100-len(count5))/100)
print(np.average(m5))
avg=0
tmp=0
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l5)
print(str(dt.timedelta(microseconds=f)))
'''
print("===============Average===================")
print((400-len(count2+count3+count4+count5))/400)
print(np.average(m2+m3+m4+m5))
avg=0
tmp=0
for i in range(len(l2)):
    date_time_obj = datetime.strptime(l2[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
for i in range(len(l3)):
    date_time_obj = datetime.strptime(l3[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l4)):
    date_time_obj = datetime.strptime(l4[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
    
    
f=avg/len(l2+l3+l4+l5)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ./bres_sarsatrace_che.csv
# ===============Average===================
# 1.0
# 22.19
# 0:00:37.035562

# %%
l5=[]
l11=[]
l15=[]
l21=[]
l25=[]

m5=[]
m11=[]
m15=[]
m21=[]
m25=[]

count5=[]
count11=[]
count15=[]
count21=[]
count25=[]

for index, row in df.iterrows():
    if row["STP_PL"]<100:
        if row["NAME"][:7]=="Maze_5_":
            l5.append(row["TIME"][7:])
            m5.append(row["STP_PL"])
        elif row["NAME"][:7]=="Maze_11":
            l11.append(row["TIME"][7:])
            m11.append(row["STP_PL"])
        elif row["NAME"][:7]=="Maze_15":
            l15.append(row["TIME"][7:])
            m15.append(row["STP_PL"])
        elif row["NAME"][:7]=="Maze_21":
            l21.append(row["TIME"][7:])
            m21.append(row["STP_PL"])
        elif row["NAME"][:7]=="Maze_25":
            l25.append(row["TIME"][7:])
            m25.append(row["STP_PL"])
    else:
        if row["NAME"][:7]=="Maze_5_":
            count5.append(row["TIME"][7:])
        elif row["NAME"][:7]=="Maze_11":
            count11.append(row["TIME"][7:])
        elif row["NAME"][:7]=="Maze_15":
            count15.append(row["TIME"][7:])
        elif row["NAME"][:7]=="Maze_21":
            count21.append(row["TIME"][7:])
        elif row["NAME"][:7]=="Maze_25":
            count25.append(row["TIME"][7:])

# %%
print((50-len(count25))/50)
print(np.average(m25))
# Out:
# 1.0
# nan
# C:\Users\marcb\anaconda3\envs\myenv\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\marcb\anaconda3\envs\myenv\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l25)):
    date_time_obj = datetime.strptime(l25[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l25)
print(str(dt.timedelta(microseconds=f)))
# Out:
# 0:27:00.935672

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l11)):
    date_time_obj = datetime.strptime(l11[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l11)
print(str(dt.timedelta(microseconds=f)))
# Out:
# 0:00:37.035562

# %%
len(m11)
# Out:
# 351

# %%
print((100-len(count5))/100)
print(np.average(m5))

print((400-len(count11))/400)
print(np.average(m11))

print((100-len(count15))/100)
print(np.average(m15))

print((100-len(count21))/100)
print(np.average(m21))

print((75-len(count25))/75)
print(np.average(m25))
# Out:
# 1.0
# nan
# 1.0
# nan
# 1.0
# nan
# 1.0
# nan
# 0.3466666666666667
# 53.69230769230769

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l11)):
    date_time_obj = datetime.strptime(l11[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l11)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41928\1666070062.py in <module>
#       9     avg+=date_time_obj.minute*60*1000000
#      10     avg+=date_time_obj.hour*60*60*1000000
# ---> 11 f=avg/len(l11)
#      12 print(str(dt.timedelta(microseconds=f)))
#
# ZeroDivisionError: division by zero

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l5)):
    date_time_obj = datetime.strptime(l5[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l5)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41928\3080994250.py in <module>
#       9     avg+=date_time_obj.minute*60*1000000
#      10     avg+=date_time_obj.hour*60*60*1000000
# ---> 11 f=avg/len(l5)
#      12 print(str(dt.timedelta(microseconds=f)))
#
# ZeroDivisionError: division by zero

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l11)):
    date_time_obj = datetime.strptime(l11[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l11)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41928\1666070062.py in <module>
#       9     avg+=date_time_obj.minute*60*1000000
#      10     avg+=date_time_obj.hour*60*60*1000000
# ---> 11 f=avg/len(l11)
#      12 print(str(dt.timedelta(microseconds=f)))
#
# ZeroDivisionError: division by zero

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l15)):
    date_time_obj = datetime.strptime(l15[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l15)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41928\3761778340.py in <module>
#       9     avg+=date_time_obj.minute*60*1000000
#      10     avg+=date_time_obj.hour*60*60*1000000
# ---> 11 f=avg/len(l15)
#      12 print(str(dt.timedelta(microseconds=f)))
#
# ZeroDivisionError: division by zero

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l21)):
    date_time_obj = datetime.strptime(l21[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l21)
print(str(dt.timedelta(microseconds=f)))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41928\1684011094.py in <module>
#       9     avg+=date_time_obj.minute*60*1000000
#      10     avg+=date_time_obj.hour*60*60*1000000
# ---> 11 f=avg/len(l21)
#      12 print(str(dt.timedelta(microseconds=f)))
#
# ZeroDivisionError: division by zero

# %%
from datetime import datetime
import datetime as dt 
avg=0
tmp=0
for i in range(len(l25)):
    date_time_obj = datetime.strptime(l25[i],'%H:%M:%S.%f')
    avg+=date_time_obj.microsecond
    avg+=date_time_obj.second*1000000
    avg+=date_time_obj.minute*60*1000000
    avg+=date_time_obj.hour*60*60*1000000
f=avg/len(l25)
print(str(dt.timedelta(microseconds=f)))
# Out:
# 0:36:25.327900
